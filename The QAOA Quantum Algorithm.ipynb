# %% [markdown]
# # Quantum Approximate Optimization Algorithm (QAOA)
# #### ColibriTD
#
# Original work by Hamza JAFFALI - hamza.jaffali@colibritd.com, Henri DE BOUTRAY - henri.de.boutray@colibritd.com, and Julien CALISTO - julien.calisto@colibritd.com, adapted for CentraleSupelec students by Timothé PRESLES - timothe.presles@colibritd.com.

# %%
# SDK install

# !pip install mpqp --upgrade
# Out:
# Requirement already satisfied: mpqp in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (0.5.0)
# Requirement already satisfied: wheel in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (0.46.3)
# Requirement already satisfied: numpy>=1.26.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.16.3)
# Requirement already satisfied: amazon-braket-sdk==1.79.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.79.1)
# Requirement already satisfied: aws-configure==2.1.8 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (2.1.8)
# Requirement already satisfied: boto3==1.35.82 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.35.82)
# Requirement already satisfied: osqp==1.0.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.0.1)
# Requirement already satisfied: amazon-braket-default-simulator==1.23.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.23.2)
# Requirement already satisfied: myqlm==1.10.6 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.10.6)
# Requirement already satisfied: myqlm-interop in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.10.0)
# Requirement already satisfied: cvxpy==1.4.3 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.4.3)
# Requirement already satisfied: qiskit==1.2.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.2.4)
# Requirement already satisfied: qiskit-ibm-runtime==0.31.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (0.31.0)
# Requirement already satisfied: qiskit-aer==0.15.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (0.15.1)
# Requirement already satisfied: azure-quantum==3.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (3.1.0)
# Requirement already satisfied: python_dotenv>=1.0.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.2.1)
# Requirement already satisfied: jsonschema>=4.17.3 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (4.26.0)
# Requirement already satisfied: typeguard>=4.2.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (4.5.0)
# Requirement already satisfied: pylatexenc==2.10 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (2.10)
# Requirement already satisfied: anytree>=2.12.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (2.13.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.13.1)
# Requirement already satisfied: pick==2.2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (2.2.0)
# Requirement already satisfied: termcolor==2.4.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (2.4.0)
# Requirement already satisfied: aenum==3.1.15 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (3.1.15)
# Requirement already satisfied: symengine>=0.11.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (0.13.0)
# Requirement already satisfied: cirq-core==1.3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: qsimcirq in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (0.22.0)
# Requirement already satisfied: cirq-google==1.3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: cirq-ionq==1.3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: cirq-aqt==1.3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: numba==0.60.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from mpqp) (0.60.0)
# Requirement already satisfied: opt-einsum in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (3.4.0)
# Requirement already satisfied: pydantic>2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (2.12.5)
# Requirement already satisfied: antlr4-python3-runtime==4.9.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (4.9.2)
# Requirement already satisfied: amazon-braket-schemas>=1.21.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (1.29.0)
# Requirement already satisfied: oqpy~=0.3.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (0.3.9)
# Requirement already satisfied: backoff in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (2.2.1)
# Requirement already satisfied: boltons in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (25.0.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (2.2.1)
# Requirement already satisfied: nest-asyncio in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.6.0)
# Requirement already satisfied: networkx in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (3.6.1)
# Requirement already satisfied: openpulse in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.0.1)
# Requirement already satisfied: openqasm3 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.0.1)
# Requirement already satisfied: backports.entry-points-selectable in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.3.0)
# Requirement already satisfied: awscli in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from aws-configure==2.1.8->mpqp) (1.36.40)
# Requirement already satisfied: botocore in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from aws-configure==2.1.8->mpqp) (1.35.99)
# Requirement already satisfied: azure-core<2.0,>=1.30 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (1.38.1)
# Requirement already satisfied: azure-identity<2.0,>=1.17 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (1.25.2)
# Requirement already satisfied: azure-storage-blob==12.20 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (12.20.0)
# Requirement already satisfied: msrest<1.0,>=0.7.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (0.7.1)
# Requirement already satisfied: deprecated<2.0,>=1.2.12 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (1.3.1)
# Requirement already satisfied: Markdown>=3.4.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (3.10.2)
# Requirement already satisfied: python-markdown-math>=0.8 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (0.9)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-storage-blob==12.20->azure-quantum==3.1.0->mpqp) (46.0.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-storage-blob==12.20->azure-quantum==3.1.0->mpqp) (4.15.0)
# Requirement already satisfied: isodate>=0.6.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-storage-blob==12.20->azure-quantum==3.1.0->mpqp) (0.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from boto3==1.35.82->mpqp) (1.1.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from boto3==1.35.82->mpqp) (0.10.4)
# Requirement already satisfied: requests~=2.18 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-aqt==1.3.0->mpqp) (2.32.5)
# Requirement already satisfied: duet~=0.2.8 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (0.2.9)
# Requirement already satisfied: matplotlib~=3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (3.10.8)
# Requirement already satisfied: pandas in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (3.0.1)
# Requirement already satisfied: sortedcontainers~=2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (2.4.0)
# Requirement already satisfied: tqdm in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (4.67.3)
# Requirement already satisfied: google-api-core>=1.14.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (2.29.0)
# Requirement already satisfied: proto-plus>=1.20.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-google==1.3.0->mpqp) (1.27.1)
# Requirement already satisfied: protobuf>=3.15.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cirq-google==1.3.0->mpqp) (6.33.5)
# Requirement already satisfied: ecos>=2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (2.0.14)
# Requirement already satisfied: clarabel>=0.5.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (0.11.1)
# Requirement already satisfied: scs>=3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (3.2.11)
# Requirement already satisfied: pybind11 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (3.0.2)
# Requirement already satisfied: qat-comm==1.6.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.6.1)
# Requirement already satisfied: qat-core==1.10.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.10.0)
# Requirement already satisfied: qat-devices==0.3.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.3.0)
# Requirement already satisfied: qat-fusion==0.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.1.0)
# Requirement already satisfied: qat-lang==3.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (3.1.0)
# Requirement already satisfied: qat-anapli==0.0.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.0.1)
# Requirement already satisfied: qat-variational==1.5.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.5.0)
# Requirement already satisfied: qlmaas==1.10.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.10.2)
# Requirement already satisfied: myqlm-clinalg==0.2.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.2.4)
# Requirement already satisfied: myqlm-contrib==1.9.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.9.5)
# Requirement already satisfied: myqlm-fermion==1.1.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.1.4)
# Requirement already satisfied: myqlm-simulators==1.9.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.9.5)
# Requirement already satisfied: bitstring in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from myqlm-fermion==1.1.4->myqlm==1.10.6->mpqp) (4.3.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from numba==0.60.0->mpqp) (0.43.0)
# Requirement already satisfied: jinja2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from osqp==1.0.1->mpqp) (3.1.6)
# Requirement already satisfied: setuptools in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from osqp==1.0.1->mpqp) (82.0.0)
# Requirement already satisfied: joblib in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from osqp==1.0.1->mpqp) (1.5.3)
# Requirement already satisfied: thrift==0.20.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-comm==1.6.1->myqlm==1.10.6->mpqp) (0.20.0)
# Requirement already satisfied: wand in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.6.13)
# Requirement already satisfied: dill in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.4.1)
# Requirement already satisfied: Pillow in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (12.1.1)
# Requirement already satisfied: svgwrite in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (1.4.3)
# Requirement already satisfied: jax[cpu] in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.7.1)
# Requirement already satisfied: IPython in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (9.10.0)
# Requirement already satisfied: ply==3.11 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-lang==3.1.0->myqlm==1.10.6->mpqp) (3.11)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit==1.2.4->mpqp) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit==1.2.4->mpqp) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit==1.2.4->mpqp) (5.6.0)
# Requirement already satisfied: psutil>=5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-aer==0.15.1->mpqp) (7.2.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (2.6.3)
# Requirement already satisfied: websocket-client>=1.5.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (1.9.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (0.73.2)
# Requirement already satisfied: prompt-toolkit in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (3.0.52)
# Requirement already satisfied: prettytable in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (3.17.0)
# Requirement already satisfied: pyOpenSSL in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (25.3.0)
# Requirement already satisfied: cffi in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (2.0.0)
# Requirement already satisfied: qat-hardware>=1.4.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (1.6.0)
# Requirement already satisfied: qat-quops>=1.3.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (1.5.0)
# Requirement already satisfied: packaging in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (26.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from sympy==1.13.1->mpqp) (1.3.0)
# Requirement already satisfied: six>=1.7.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from thrift==0.20.0->qat-comm==1.6.1->myqlm==1.10.6->mpqp) (1.17.0)
# Requirement already satisfied: msal>=1.31.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-identity<2.0,>=1.17->azure-quantum==3.1.0->mpqp) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-identity<2.0,>=1.17->azure-quantum==3.1.0->mpqp) (1.3.1)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from deprecated<2.0,>=1.2.12->azure-quantum==3.1.0->mpqp) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from msrest<1.0,>=0.7.1->azure-quantum==3.1.0->mpqp) (2026.1.4)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from msrest<1.0,>=0.7.1->azure-quantum==3.1.0->mpqp) (2.0.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from oqpy~=0.3.5->amazon-braket-sdk==1.79.1->mpqp) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from requests~=2.18->cirq-aqt==1.3.0->mpqp) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from requests~=2.18->cirq-aqt==1.3.0->mpqp) (3.11)
# Requirement already satisfied: pycparser in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from cffi->qlmaas==1.10.2->myqlm==1.10.6->mpqp) (3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (1.72.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (2.48.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (0.6.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (1.78.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime==0.31.0->mpqp) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.22.6->qiskit-ibm-runtime==0.31.0->mpqp) (2.11.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator==1.23.2->mpqp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator==1.23.2->mpqp) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator==1.23.2->mpqp) (0.4.2)
# Requirement already satisfied: qutip in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qat-hardware>=1.4.0->qlmaas==1.10.2->myqlm==1.10.6->mpqp) (5.2.3)
# Requirement already satisfied: pyspnego>=0.4.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime==0.31.0->mpqp) (0.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0,>=0.7.1->azure-quantum==3.1.0->mpqp) (3.3.1)
# Requirement already satisfied: docutils<0.17,>=0.10 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from awscli->aws-configure==2.1.8->mpqp) (0.16)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from awscli->aws-configure==2.1.8->mpqp) (6.0.3)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from awscli->aws-configure==2.1.8->mpqp) (0.4.6)
# Requirement already satisfied: qiskit-ionq<0.6,>=0.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum[qiskit]->mpqp) (0.5.13)
# Requirement already satisfied: qsharp<2.0,>=1.9.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qsharp[qiskit]<2.0,>=1.9.0; extra == "qiskit"->azure-quantum[qiskit]->mpqp) (1.25.1)
# Requirement already satisfied: pyqir<0.11,>=0.10.6 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from azure-quantum[qiskit]->mpqp) (0.10.9)
# Requirement already satisfied: decorator>=5.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-ionq<0.6,>=0.5->azure-quantum[qiskit]->mpqp) (5.2.1)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qiskit-ionq<0.6,>=0.5->azure-quantum[qiskit]->mpqp) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from importlib-metadata>=4.11.4->qiskit-ionq<0.6,>=0.5->azure-quantum[qiskit]->mpqp) (3.23.0)
# Requirement already satisfied: bitarray<4.0,>=3.0.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from bitstring->myqlm-fermion==1.1.4->myqlm==1.10.6->mpqp) (3.8.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (4.9.0)
# Requirement already satisfied: pygments>=2.11.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from prompt-toolkit->qlmaas==1.10.2->myqlm==1.10.6->mpqp) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from pexpect>4.3->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.2.3)
# Requirement already satisfied: jaxlib<=0.7.1,>=0.7.1 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jax[cpu]->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.7.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jax[cpu]->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from jinja2->osqp==1.0.1->mpqp) (3.0.3)
# Requirement already satisfied: absl-py in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from qsimcirq->mpqp) (2.4.0)
# Requirement already satisfied: pybind11-global==3.0.2 in /Users/paulv/Documents/CS/ST7-Quantum_Computing/.venv/lib/python3.12/site-packages (from pybind11[global]->qsimcirq->mpqp) (3.0.2)

# %%
import mpqp

from mpqp.tools import Matrix
from mpqp.measures import I, Z, Y, X, PauliString

# %% [markdown]
# ## Preamble
#
# In the previous import, the functions "I, Z, Y, and X" are imported. **THESE ARE NOT QUANTUM GATES** but observables!!!
#
# This is a distinction that is quite intuitive at first glance. Here, these mathematical objects are used to "encode" information into the Hamiltonian, but not directly to perform an operation (as you will see later, we will use an exponential to encode our quantum gates). In short, this is not fundamental for understanding this TP, but I had to tell you to be strictly rigorous. Moreover, in the upcoming version of MPQP (probably the next one), these observables will be denoted as 'pI, pX, pY, and pZ' to avoid confusion!

# %% [markdown]
# ## The Variational Quantum Algorithm: QAOA (Quantum Approximate Optimization Algorithm)
#
# #### Let's review the principle of the algorithm
#
# The QAOA algorithm is a well-known member of the Variational Quantum Algorithm (VQA) class. Its successful operation requires 3 main ingredients:
#
# * **A cost function**, encoding the optimization problem we want to solve, modeled by a Hamiltonian $H_C$.
# * **An Ansatz** describing the architecture of the quantum circuit used to amplify the probabilities of optimal solutions, including our cost Hamiltonian $H_C$ and a "mixing" Hamiltonian $H_M$. As a reminder, Hamiltonians are found in the Schrödinger equation, and they are the same operators introduced when we talked about quantum annealing.
# * **A classical optimizer** to search for the optimal parameters of our quantum circuit (very similar to the optimizers used in neural networks).
#
# In this TP, we will develop our own QAOA using the MPQP quantum programming library developed by the startup ColibriTD. The idea is to solve a simple problem: Find the minimum of a function $C(x)$, defined as:
#
# $$C(x) = 3x_0x_1 - 4x_0 - 2x_1 + 1$$
#
# The first step is to define a Hamiltonian $H_C$. We seek to define it such that its ground state (minimum energy) corresponds to the minimum of the cost function. This function has two variables $x_0$ and $x_1$. Thus, we will use a two-qubit system $\ket{x}=\ket{x_0x_1}$ encoding a superposition of the four possible binary combinations.
#
# Subsequently, we will use the following relationship to define our Hamiltonians from mathematical functions, such as our cost function:
#
# $$
# x_i = \frac{I^{\otimes n} - Z_i}{2}
# $$
# $$
# \text{with } ~~ Z_i = \underbrace{I \otimes \cdots \otimes I}_{i} \otimes Z \otimes \underbrace{I \otimes \cdots \otimes I}_{n-i-1}
# $$

# %% [markdown]
# > **_IMPORTANT:_** **In the case of PauliString in MPQP**, the Kronecker product $\otimes$ is written as "@".
# >
# > Do not confuse this with the matrix product in numpy, which for two matrices $A$ and $B$ is written the same way but performs $A \times B$ instead of $A \otimes B$ !!!
# > Here, we will use @ exclusively within the context of PauliString.

# %% [markdown]
# **1) Write a Python function that returns the Hamiltonian $H_C$ associated with the cost function:**

# %%
def hamiltonian_cost() -> PauliString:
    return ((3 * ((I - Z)/2)@((I - Z)/2)) - (4 * ((I@I - Z@I)/2))) - (2 * ((I@I - I@Z)/2)) + I@I

hamiltonian_cost().to_matrix()
# Out:
# array([[ 1.+0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#        [ 0.+0.j, -1.+0.j,  0.+0.j,  0.+0.j],
#        [ 0.+0.j,  0.+0.j, -3.+0.j,  0.+0.j],
#        [ 0.+0.j,  0.+0.j,  0.+0.j, -2.+0.j]])

# %% [markdown]
# We define the mixing Hamiltonian $H_M$ as a sum of local Pauli $X_i$ observables such that:
# $$
# H_M = \sum_{i=0}^{n-1} X_i
# $$
# $$
# \text{with } ~~ X_i = \underbrace{I \otimes \cdots \otimes I}_{i} \otimes X \otimes \underbrace{I \otimes \cdots \otimes I}_{n-i-1}
# $$

# %% [markdown]
# **2) Write a Python function that returns the Hamiltonian $H_M$ associated with the mixing operator:**

# %%
def hamiltonian_mixer() -> PauliString:
    h_m = (I@X) + (X@I)
    return h_m

hamiltonian_mixer().to_matrix()
# Out:
# array([[0.+0.j, 1.+0.j, 1.+0.j, 0.+0.j],
#        [1.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#        [1.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#        [0.+0.j, 1.+0.j, 1.+0.j, 0.+0.j]])

# %% [markdown]
# Once these Hamiltonians are defined, we must create the evolution operator that will be repeated several times to amplify the probabilities of finding the lowest energy solutions, i.e., minimizing our cost function. Recall that the time evolution described by a time-independent Hamiltonian $H$ can be represented by a 1-parameter unitary operator $U(\gamma) = e^{-i\gamma H}$. This implies that we must calculate the exponential of a matrix, which is enabled by the `expm` function from the `scipy.linalg` library.
#
# > **_Tip:_** The MPQP function `PauliString.to_matrix()` allows you to convert a Pauli string object into its associated matrix.

# %%
from scipy.linalg import expm

# %% [markdown]
# **3) Write a Python function that returns $U_{C}(\gamma)$ associated with the Hamiltonian $H_C$ and the parameter $\gamma$:**

# %%
def unitary_matrix_hamiltonian_cost(gamma: float) -> Matrix:
    return expm(-1j * gamma * hamiltonian_cost().to_matrix())
    
unitary_matrix_hamiltonian_cost(1)
# Out:
# array([[ 0.54030231-0.84147098j,  0.        +0.j        ,
#          0.        +0.j        ,  0.        +0.j        ],
#        [ 0.        +0.j        ,  0.54030231+0.84147098j,
#          0.        +0.j        ,  0.        +0.j        ],
#        [ 0.        +0.j        ,  0.        +0.j        ,
#         -0.9899925 +0.14112001j,  0.        +0.j        ],
#        [ 0.        +0.j        ,  0.        +0.j        ,
#          0.        +0.j        , -0.41614684+0.90929743j]])

# %% [markdown]
# **4) Write a Python function that returns $U_{M}(\beta)$ associated with the Hamiltonian $H_M$ and the parameter $\beta$:**

# %%
def unitary_matrix_hamiltonian_mixer(beta: float) -> Matrix:
    return expm(-1j * beta * hamiltonian_mixer().to_matrix())

unitary_matrix_hamiltonian_mixer(0.2)
# Out:
# array([[ 0.9605305+0.j        ,  0.       -0.19470917j,
#          0.       -0.19470917j, -0.0394695+0.j        ],
#        [ 0.       -0.19470917j,  0.9605305+0.j        ,
#         -0.0394695+0.j        ,  0.       -0.19470917j],
#        [ 0.       -0.19470917j, -0.0394695+0.j        ,
#          0.9605305+0.j        ,  0.       -0.19470917j],
#        [-0.0394695+0.j        ,  0.       -0.19470917j,
#          0.       -0.19470917j,  0.9605305+0.j        ]])

# %% [markdown]
# The next step is to construct the "parameterized" QAOA quantum circuit, which we will denote as $U$, and which depends on $2d$ parameters $\{\gamma_1, \beta_1, \dots, \gamma_d, \beta_d\}$, where $d$ is the "depth" of our Ansatz. Recall that the QAOA circuit is composed of an alternation of unitary operators encoding the system's evolution according to the Hamiltonians $H_C$ and $H_M$, with a parameter associated with each occurrence of each operator.
#
# In other words, we have:
# $$U(\gamma_1, \beta_1, \dots, \gamma_d, \beta_d) = e^{-i\beta_d H_M}e^{-i\gamma_d H_C} \cdots e^{-i\beta_1 H_M}e^{-i\gamma_1 H_C}$$

# %% [markdown]
# **5) Write a Python function that takes the Ansatz parameters as input and returns the QAOA circuit as output:**
#
# > **_Tip:_** We must create "CustomGates", which are defined like our "gate objects" in previous Qiskit TPs. The language changes, but the logic remains strictly the same:
# >+ These are objects that we must "append" to our circuit.
# >+ Their first parameter is the unitary matrix defining the action of the quantum gate.
# >+ The second argument is the list of "target" qubits, i.e., those to which they are applied (note that if a 1-qubit gate has several "targets", then the same gate will be applied to the entire target list).

# %%
from typing import Optional

from mpqp.core.circuit import QCircuit
from mpqp.gates import Gate, CustomGate, UnitaryMatrix

def construct_qaoa_ansatz(parameters: list[float], depth: Optional[int]=None):
    if depth is None:
        if len(parameters) % 2 != 0:
            raise ValueError("parameters length must be even (2*depth).")
        depth = len(parameters) // 2

    if len(parameters) != 2 * depth:
        raise ValueError("Wrong parameters length vs depth.")

    gates: list[Gate] = []
     
    for d in range(depth):
        gamma = parameters[2 * d]
        beta  = parameters[2 * d + 1]

        gate_cost = CustomGate(unitary_matrix_hamiltonian_cost(gamma), [0,1], 'Parameterized Cost Gate')
        gate_mixer = CustomGate(unitary_matrix_hamiltonian_mixer(beta), [0,1], 'Parameterized Cost Gate')
        gates.append(gate_cost)
        gates.append(gate_mixer)
        
        
    return QCircuit(gates)

# %% [markdown]
# Let's display the circuit with some dummy parameters to check that it works correctly...

# %%
construct_qaoa_ansatz([1,2,3,4,5,6,7,8]).display(warn=False)

# %% [markdown]
# Now that we have the structure of our circuit to optimize, we focus on an important element of our algorithm: calculating the loss function to be optimized. Here, we want to minimize the cost function $C(x)$, which is equivalent to finding the ground state $\ket{\psi}$ of the cost Hamiltonian $H_C$, which can be expressed as:
#
# $$\ket{\psi} = \text{arg } \min_{\ket{x}} \ \langle x \mid H_C \mid x \rangle$$
#
# Thus, at each iteration of the algorithm, we will evaluate the expectation value of $H_C$ relative to the state produced by the parameterized circuit, and the optimizer will then update the parameters to minimize this value. We propose to calculate this expectation value using the circuit generated by the previous function along with other provided features. You can use `Observable`.
#
# **6) Implement the loss function that calculates the cost function from a provided list of input parameters:**

# %%
from mpqp.core.instruction.measurement import Observable, ExpectationMeasure
from mpqp.execution import run, AvailableDevice

# %%
def loss_function(parameters: list[float], device: AvailableDevice):
    
    # Récupérer le Hamiltonien de cout sous la forme d'une matrice pour créer l'observable
    cost_hamiltonian_matrix = hamiltonian_cost()
    observable: Observable = Observable(cost_hamiltonian_matrix)
    
    # Créer le circuit avec les fonction définies précédemment et l'observable
    circuit: QCircuit = construct_qaoa_ansatz(parameters)
    circuit.add(ExpectationMeasure(observable))
    
    # Récupérer la valeur d'espérance (expectation value / exp_value) ) partir du résultat
    result = run(circuit, device)
    print(result.expectation_values)
    exp_value = result.expectation_values
    
    return exp_value

# %% [markdown]
# The last missing element of this variational algorithm is the classical optimizer that will optimize these parameters and return the most probable solution state. We define a `solve_qaoa` function that takes an initial list of parameters to start the optimization as well as the depth of the ansatz. It calls the `minimize` function from the `scipy.optimize` package. We define a callback function to track the value of the loss function during optimization. You can adjust the optimizer parameters (method, tolerance, number of iterations, etc.) until you can find the solution. You can refer to the following documentation: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html
#
# *Feel free to test different optimizer parameters and methods in the rest of this TP, and look at their influence on the quality of the result obtained!*
#
# The *solve_qaoa* function returns two values: the vector of best parameters and the minimum value found for the cost function.

# %%
from typing import Any
from scipy.optimize import minimize

# %%
def solve_qaoa(init_params: list[float], 
               method: str, 
               device: AvailableDevice,
               options: dict[str, Any],
               depth: Optional[int]=None, 
               ):

    def obj(params):
        return loss_function(params, device=device)
    
    def callback(xk): # Fonction cosmétique, renvoie la valeur de la loss à chaque itération
        print("current loss: ", obj(xk))

    opt = minimize(obj, init_params, method=method, options=options, callback=callback)
    return opt.x, opt.fun

# %% [markdown]
# We are now ready to test the algorithm! The final step consists of initializing the set of parameters and defining the depth of the QAOA ansatz. You can then run the algorithm and check if the function has actually reached its minimum.

# %%
from mpqp.execution import IBMDevice, ATOSDevice, AWSDevice, AZUREDevice, GOOGLEDevice

# %% [markdown]
# **7) Define the optimizer hyperparameters; you can start by choosing a method and a number of iterations (associated with the 'maxiter' key in the options dictionary):**

# %%
method = 'Powell'
options = {"disp": True, "maxiterint": 10} # TODO: tune

# %% [markdown]
# **8) Define the quantum circuit hyperparameters by determining the depth (number of repetitions of operator pairs) and the initial parameters (which can be chosen randomly or not). We can also choose different "devices" (which is the strength of MPQP), but we will stay on the simulated IBM machine for this TP.**

# %%
import numpy as np

depth = 10
init_params = np.random.rand(depth*2) * 10
device = IBMDevice.AER_SIMULATOR # Littéralement celui utilisé dans nos TPs sur Qiskit

best_params, best_value = solve_qaoa(init_params, method, device, options, depth)
print(best_params, best_value)
# Out:
# /var/folders/xq/bncnvz1j45v3mfq3lcdw025w0000gn/T/ipykernel_77093/1995017958.py:14: OptimizeWarning: Unknown solver options: maxiterint
#   opt = minimize(obj, init_params, method=method, options=options, callback=callback)
# -1.1919180353912988
# -1.1919180353912988
# -1.1919180353912977
# -1.191918035391297
# -1.191918035391298
# -1.1919180353912975
# -1.1919180353912977
# -1.191918035391298
# -1.1919180353912981
# -1.1919180353912977
# -1.1919180353912973
# -1.191918035391298
# -1.1919180353912973
# -1.1919180353912973
# -1.1919180353912986
# -1.1919180353912984
# -1.1919180353912977
# -1.1919180353912973
# -1.191918035391298
# -1.1919180353912973
# -1.1919180353912986
# -2.9999213467347925
# -2.999955928282518
# -2.9999559280156225
# -2.999955927684424
# -2.999955928282518
# -0.9974953486440401
# -2.201227403105749
# -0.9291762206190165
# -1.9867846875343584
# -2.992562996244559
# -2.999877960250993
# -2.9999580761064992
# -2.999958076011425
# -2.999958075774366
# -2.9999580761064992
# -1.4690927289432432
# -1.3743221807096146
# -2.3923022115934978
# -2.6986705214420894
# -2.9981708213806555
# -2.9999664791789034
# -2.999966488079252
# -2.99996648762934
# -2.999966486839347
# -2.999966488079252
# -1.8165913057578456
# -1.4939337594677846
# -2.0549873310543347
# -2.64468328867377
# -2.999970136245774
# -2.9999712182039455
# -2.999971233885303
# -2.9999712334172624
# -2.999971233404307
# -2.999971233885303
# -1.5702047190058006
# -0.6957100488743101
# -2.1314204543578277
# -2.65699777006911
# -2.9998998661859035
# -2.9999758545903497
# -2.999976421998551
# -2.9999764214974998
# -2.9999764214624904
# -2.999976421998551
# -1.8827002718960246
# -2.0418383071313024
# -2.050152244501488
# -2.5709403709142995
# -2.9986170971839936
# -2.999964817702741
# -2.999977600491355
# -2.9999776004424032
# -2.9999776003059617
# -2.999977600491355
# -0.7610170771157878
# -1.5202520315798616
# -1.3276325351780374
# -2.1790848997611483
# -2.993612757588358
# -2.999944662307971
# -2.9999816613681727
# -2.9999816610491887
# -2.9999816608767014
# -2.9999816613681727
# -0.9636485479191428
# -0.9977305301482673
# -1.6602128356634607
# -2.3632384221891396
# -2.9965196868217263
# -2.999966133884918
# -2.9999816706498934
# -2.9999816706514117
# -2.999981670650482
# -2.9999816706514117
# current loss:  -2.9999816706514117
# Optimization terminated successfully.
#          Current function value: -2.999982
#          Iterations: 4
#          Function evaluations: 835
# [7.31205699 0.71527478 4.32999471 6.12115022 9.38288277 8.13609285
#  7.76283979 6.36090559 0.08317984 6.03235956 8.90413243 1.03941081
#  7.94490442 0.45291639 8.24996709 3.39257839 4.07805744 4.23193623
#  5.71908162 7.12441321] -2.9999816706514117

# %% [markdown]
# The algorithm produces a state for which the solution is encoded in the basis state with the highest measurement probability. To retrieve the most probable solution, we must sample the circuit with the best parameters. The binary representation of the basis states gives us the assignment of variables as a possible solution. You can run the following code snippet and verify that it returns the correct solution.

# %%
from mpqp.measures import BasisMeasure

# %%
qcircuit_best = construct_qaoa_ansatz(best_params)
qcircuit_best.add(BasisMeasure())
sol_res = run(qcircuit_best, device)
print(sol_res)

print("\nMost probable states are:")
for sample in sol_res.samples:
    if sample.probability > 0.09:
        s = sample.bin_str
        print(f"|{s}>", "{:.2f}%".format(100 * sample.probability), "--> Solution: {x_0 =",s[0], ", x_1 =",s[1]+"}")
# Out:
# Result: IBMDevice, AER_SIMULATOR
#   Counts: [0, 0, 1024, 0]
#   Probabilities: [0, 0, 1, 0]
#   Samples:
#     State: 10, Index: 2, Count: 1024, Probability: 1
#   Error: None
#
# Most probable states are:
# |10> 100.00% --> Solution: {x_0 = 1 , x_1 = 0}

# %% [markdown]
# Congratulations, you have implemented a variational QAOA algorithm! To go further, feel free to complicate the initial cost function (by adding a variable and a term where they multiply each other) and redo the TP with it. You will certainly observe that the necessary circuit depth as well as the number of iterations increase slightly.
